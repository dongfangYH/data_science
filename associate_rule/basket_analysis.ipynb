# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# load data
data = pd.read_csv('../data/basket/Assignment-1_Data.csv', delimiter=';')
data.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522064 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    522064 non-null  int64
#  3   Date        522064 non-null  object
#  4   Price       522064 non-null  object
#  5   CustomerID  388023 non-null  float64
#  6   Country     522064 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
# 数据清洗
data.dropna(subset=['Itemname'], inplace=True)
data['Price'] = data['Price'].str.replace(',','.').astype('float64')
# sns.boxplot(data[['price']])
data = data[data['Price'] > 0]
data = data[data['Country'] == 'United Kingdom']
data['Total price']=data.Quantity * data.Price
data.info()
#data = data.dropna()
#data = data.drop_duplicates()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 485123 entries, 0 to 522048
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BillNo       485123 non-null  object
#  1   Itemname     485123 non-null  object
#  2   Quantity     485123 non-null  int64
#  3   Date         485123 non-null  object
#  4   Price        485123 non-null  float64
#  5   CustomerID   354321 non-null  float64
#  6   Country      485123 non-null  object
#  7   Total price  485123 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 33.3+ MB

# %%
data = data.loc[
    (data['Itemname']!= 'Adjust bad debt') & 
    (data['Itemname']!= 'AMAZON FEE') & 
    (data['Itemname']!= 'Bank Charges') &
    (data['Itemname']!= 'DOTCOM POSTAGE') & 
    (data['Itemname']!= 'Dotcomgiftshop Gift Voucher Â£10.00') &
    (data['Itemname']!= 'Dotcomgiftshop Gift Voucher Â£100.00') &
    (data['Itemname']!= 'Dotcomgiftshop Gift Voucher Â£20.00') & 
    (data['Itemname']!= 'Dotcomgiftshop Gift Voucher Â£30.00') & 
    (data['Itemname']!= 'Dotcomgiftshop Gift Voucher Â£40.00') & 
    (data['Itemname']!= 'Dotcomgiftshop Gift Voucher Â£50.00') & 
    (data['Itemname']!= 'Manual') & 
    (data['Itemname']!= 'POSTAGE') &
    (data['Itemname']!= 'SAMPLES')
]

# %%
data['Country'].value_counts()
# Out:
# Country
# United Kingdom    484036
# Name: count, dtype: int64

# %%
data['Year']=data['Date'].apply(lambda x:x.split('.')[2])
data['Year']=data['Year'].apply(lambda x:x.split(' ')[0])
data['Month']=data['Date'].apply(lambda x:x.split('.')[1])

data.groupby(['Year','Month'])['Total price'].sum()
# Out:
# Year  Month
# 2010  12        707469.610
# 2011  01        547167.610
#       02        418983.950
#       03        573123.130
#       04        466182.151
#       05        619541.150
#       06        606270.960
#       07        578274.681
#       08        579975.270
#       09        878329.111
#       10        914878.250
#       11       1286474.780
#       12        572282.680
# Name: Total price, dtype: float64

# %%
data=data.loc[data['Year']!='2010']

# %%
# 使用value_counts()对Category列进行分类统计
#category_counts = data['Itemname'].value_counts().reset_index()
#category_counts.columns = ['Itemname', 'Count']

# 按照分类统计结果创建新的DataFrame
#category_counts_df = pd.DataFrame(category_counts)

# 将分类统计结果保存到本地文件，比如CSV格式
#category_counts_df.to_csv('category_counts.csv', index=False)

# %%
data.head()
# Out:
#        BillNo                   Itemname  Quantity              Date  Price  \
# 41242  539993    JUMBO BAG PINK POLKADOT        10  04.01.2011 10:00   1.95
# 41243  539993         BLUE POLKADOT WRAP        25  04.01.2011 10:00   0.42
# 41244  539993         RED RETROSPOT WRAP        25  04.01.2011 10:00   0.42
# 41245  539993    RECYCLING BAG RETROSPOT         5  04.01.2011 10:00   2.10
# 41246  539993  RED RETROSPOT SHOPPER BAG        10  04.01.2011 10:00   1.25
#
#        CustomerID         Country  Total price  Year Month
# 41242     13313.0  United Kingdom         19.5  2011    01
# 41243     13313.0  United Kingdom         10.5  2011    01
# 41244     13313.0  United Kingdom         10.5  2011    01
# 41245     13313.0  United Kingdom         10.5  2011    01
# 41246     13313.0  United Kingdom         12.5  2011    01

# %%
data = data[data['Country']=='United Kingdom']
transactions = data.groupby('BillNo')['Itemname'].apply(list).tolist()
transactions = [transaction for transaction in transactions if len(transaction) >= 2]
len(transactions)
# Out:
# 15228

# %%
# One-hot encode transactions
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Apply Apriori algorithm
frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True, low_memory=True)

# %%
# Print frequent itemsets
print(frequent_itemsets)
# Out:
#       support                                           itemsets
# 0    0.022065                 (3 HOOK PHOTO SHELF ANTIQUE WHITE)
# 1    0.025873                         (3 STRIPEY MICE FELTCRAFT)
# 2    0.023115                      (4 TRADITIONAL SPINNING TOPS)
# 3    0.051681                           (6 RIBBONS RUSTIC CHARM)
# 4    0.022459                  (60 CAKE CASES DOLLY GIRL DESIGN)
# ..        ...                                                ...
# 469  0.023378  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 470  0.025479  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SU...
# 471  0.024297  (JUMBO BAG RED RETROSPOT, JUMBO SHOPPER VINTAG...
# 472  0.021671  (LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROS...
# 473  0.020489  (LUNCH BAG SUKI DESIGN, LUNCH BAG RED RETROSPO...
#
# [474 rows x 2 columns]

# %%
# 使用关联规则查找频繁项集
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
rules
# Out:
#                                           antecedents  \
# 0                       (CHARLOTTE BAG PINK POLKADOT)
# 1                 (GARDENERS KNEELING PAD CUP OF TEA)
# 2                    (PINK REGENCY TEACUP AND SAUCER)
# 3                   (GREEN REGENCY TEACUP AND SAUCER)
# 4                   (ROSES REGENCY TEACUP AND SAUCER)
# 5                    (PINK REGENCY TEACUP AND SAUCER)
# 6                      (SMALL MARSHMALLOWS PINK BOWL)
# 7               (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 8                (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 9   (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 10  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# 11  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...
# 12                   (PINK REGENCY TEACUP AND SAUCER)
# 13  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...
# 14  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...
# 15  (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG PIN...
# 16  (JUMBO BAG WOODLAND ANIMALS, JUMBO BAG PINK PO...
# 17  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 18  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 19  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO STOR...
#
#                                           consequents  antecedent support  \
# 0                       (RED RETROSPOT CHARLOTTE BAG)            0.041240
# 1                  (GARDENERS KNEELING PAD KEEP CALM)            0.049186
# 2                   (GREEN REGENCY TEACUP AND SAUCER)            0.045640
# 3                   (ROSES REGENCY TEACUP AND SAUCER)            0.057197
# 4                   (GREEN REGENCY TEACUP AND SAUCER)            0.058314
# 5                   (ROSES REGENCY TEACUP AND SAUCER)            0.045640
# 6                (SMALL DOLLY MIX DESIGN ORANGE BOWL)            0.027646
# 7                (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.031587
# 8               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.029485
# 9                   (ROSES REGENCY TEACUP AND SAUCER)            0.037628
# 10                  (GREEN REGENCY TEACUP AND SAUCER)            0.035658
# 11                   (PINK REGENCY TEACUP AND SAUCER)            0.042882
# 12  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENC...            0.045640
# 13                  (ROSES REGENCY TEACUP AND SAUCER)            0.027121
# 14                  (GREEN REGENCY TEACUP AND SAUCER)            0.027318
# 15                          (JUMBO BAG RED RETROSPOT)            0.025742
# 16                          (JUMBO BAG RED RETROSPOT)            0.025217
# 17                          (JUMBO BAG RED RETROSPOT)            0.029091
# 18                          (JUMBO BAG RED RETROSPOT)            0.031718
# 19                          (JUMBO BAG RED RETROSPOT)            0.032309
#
#     consequent support   support  confidence       lift  leverage  conviction  \
# 0             0.055687  0.029157    0.707006  12.696100  0.026860    3.222982
# 1             0.058905  0.035527    0.722296  12.262129  0.032629    3.388848
# 2             0.057197  0.037628    0.824460  14.414332  0.035018    5.370884
# 3             0.058314  0.042882    0.749713  12.856564  0.039546    3.762426
# 4             0.057197  0.042882    0.735360  12.856564  0.039546    3.562591
# 5             0.058314  0.035658    0.781295  13.398153  0.032997    4.305737
# 6             0.032506  0.021605    0.781473  24.040941  0.020706    4.427337
# 7             0.029485  0.023181    0.733888  24.890072  0.022250    3.647013
# 8             0.031587  0.023181    0.786192  24.890072  0.022250    4.529350
# 9             0.058314  0.032178    0.855148  14.664638  0.029983    6.501040
# 10            0.057197  0.032178    0.902394  15.776874  0.030138    9.659281
# 11            0.045640  0.032178    0.750383  16.441482  0.030220    3.823297
# 12            0.042882  0.032178    0.705036  16.441482  0.030220    3.244865
# 13            0.058314  0.021474    0.791768  13.577744  0.019892    4.522285
# 14            0.057197  0.021474    0.786058  13.742924  0.019911    4.406808
# 15            0.118794  0.020095    0.780612   6.571124  0.017037    4.016658
# 16            0.118794  0.020095    0.796875   6.708022  0.017099    4.338243
# 17            0.118794  0.023378    0.803612   6.764732  0.019922    4.487059
# 18            0.118794  0.025479    0.803313   6.762214  0.021711    4.480235
# 19            0.118794  0.024297    0.752033   6.330542  0.020459    3.553715
#
#     zhangs_metric
# 0        0.960861
# 1        0.965959
# 2        0.975129
# 3        0.978167
# 4        0.979327
# 5        0.969616
# 6        0.985654
# 7        0.991130
# 8        0.988984
# 9        0.968242
# 10       0.971249
# 11       0.981256
# 12       0.984092
# 13       0.952174
# 14       0.953277
# 15       0.870220
# 16       0.872937
# 17       0.877708
# 18       0.880032
# 19       0.870149
