# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
data = pd.read_excel('../data/basket/Assignment-1_Data.xlsx')
data = data.dropna()

# %%
# 数据预处理：将 Itemname 转换为 One-Hot 编码
df_encoded = pd.get_dummies(data['Itemname'])
df_encoded
# Out:
#         10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 522059                   False                       False
# 522060                   False                       False
# 522061                   False                       False
# 522062                   False                       False
# 522063                   False                       False
#
#         12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# ...

# %%
# 将编码后的数据与原始数据合并
df = pd.concat([data, df_encoded], axis=1)
df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                       Date  Price  CustomerID         Country  \
# 0      2010-12-01 08:26:00   2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00   3.39     17850.0  United Kingdom
# ...

# %%
# 使用 Apriori 算法计算频繁项集
frequent_itemsets = apriori(df.drop(['BillNo', 'Itemname', 'Date', 'CustomerID', 'Country'], axis=1), min_support=0.2, use_colnames=True, low_memory=True)
# 打印频繁项集
print(frequent_itemsets)
# Out:
# c:\Users\henry\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[23], line 2
#       1 # 使用 Apriori 算法计算频繁项集
# ----> 2 frequent_itemsets = apriori(df.drop(['BillNo', 'Itemname', 'Date', 'CustomerID', 'Country'], axis=1), min_support=0.2, use_colnames=True, low_memory=True)
#       3 # 打印频繁项集
#       4 print(frequent_itemsets)
#
# File c:\Users\henry\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\apriori.py:241, in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     234 if min_support <= 0.0:
#     235     raise ValueError(
# ...
